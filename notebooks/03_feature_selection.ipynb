# %% [markdown]
# ## Feature selection

# %%
#  %%capture
# %pip install -r ../../requirements.txt

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np
from IPython.display import clear_output

cwd = Path.cwd()  # Current directory
sys.path.append(str(cwd.parents[0]))
from feature_selection_function import perform_rfe,select_rfe_model
from definitions import LocationConfig
lc = LocationConfig()

# %%
# Read train/test data for feature selection
df_raw_data = pd.read_csv(lc.feature_transformation_output_table)

# %%
df_raw_data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# Identiy non feature columns which needs to be removed 
columns_to_drop = []
target_variable = 'price_range' # Replace with your target column

# %%
# Drop the columns which won't contribute to feature selection
df_raw_data = df_raw_data.drop(columns_to_drop, axis=1)

# %%
# Differentiate Features and Target variable
X_features = df_raw_data.drop(target_variable, axis=1)  # Features
y_target = df_raw_data[target_variable]  # Target variable

# %%
# %%time
# Number of features to select
n_features_to_select = 15
selected_model = "LogisticRegression" # Replace with your selected model
selected_features = select_rfe_model(selected_model, X_features, y_target, n_features_to_select)

df_features = pd.DataFrame(selected_features, columns=['Feature'])
# Out:
# C:\Users\LivinAlbert\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\LivinAlbert\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
df_features
# Out:
#          Feature
# 0           blue
# 1    clock_speed
# 2       dual_sim
# 3             fc
# 4         four_g
# 5     int_memory
# 6          m_dep
# 7        n_cores
# 8             pc
# 9           sc_h
# 10          sc_w
# 11     talk_time
# 12       three_g
# 13  touch_screen
# 14          wifi

# %%
# Save the selected features
df_features.to_csv(lc.selected_features_table_name,index=False)
